# %% [markdown]
# # Pyfar: Try it Yourself
#
# You've checked out some of the [getting started](https://pyfar-gallery.readthedocs.io/en/latest/examples_gallery.html) or other Notebooks on [pyfar.org](https://pyfar.org) and want to try pyfar yourself?
#
# This notebook is for you - click the **launch binder** button above and start coding!

# %% [markdown]
# We added some imports that you might need. Run the below first:

# %%
# import pyfar packages
import pyfar as pf
import pyrato
import spharpy
import sofar
# import common other packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Now try what you have in mind below. If you run into problems [pyfar.org](https://pyfar.org) is there for you to help.

# %%
# your code goes here...
